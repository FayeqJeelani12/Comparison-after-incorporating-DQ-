# %%
import pandas as pd
df = pd.read_csv("datafiles/Comparison.csv")

# %%
df.head(10)
# Out:
#    DONOR_ID     AB_EMS     AB_HMS  AB_AMS   DR_EMS  DR_HMS  DR_AMS    Avg_EMS  \
# 0    218478   9.049286  12.285714    6.00   4.2150   6.750     5.0   6.632143
# 1    132149   9.049286  12.285714    6.00   4.2150   6.750     5.0   6.632143
# 2    132149   9.049286  12.285714    6.00   4.2150   6.750     5.0   6.632143
# 3    132149  13.862500  18.000000   10.00   4.2150   6.750     5.0   9.038750
# 4    132149  13.862500  18.000000   10.00   4.2150   6.750     5.0   9.038750
# 5     76722   4.875000   6.075000    3.00  16.2150  16.500    11.5  10.545000
# 6     76722   4.875000   6.075000    3.00  16.2150  16.500    11.5  10.545000
# 7     76722   1.138750   1.500000    1.25   8.7375  10.525     7.0   4.938125
# 8     76722   1.138750   1.500000    1.25   8.7375  10.525     7.0   4.938125
# 9    181064   1.138750   1.500000    1.25   8.7375  10.525     7.0   4.938125
#
#      Avg_HMS  Avg_AMS  PERS_ID  AB_EMS_DQ  AB_HMS_DQ  AB_AMS_DQ  DR_EMS_DQ  \
# 0   9.517857    5.500  3757327   9.549286  13.085714   6.142857   5.124375
# 1   9.517857    5.500  3757327   9.549286  13.085714   6.142857   5.124375
# 2   9.517857    5.500  3219862  13.862500  18.000000  10.000000  10.957500
# 3  12.375000    7.500  3757327   9.549286  13.085714   6.142857   5.124375
# 4  12.375000    7.500  3219862  13.862500  18.000000  10.000000  10.957500
# 5  11.287500    7.250  3245171   4.875000   6.075000   3.000000  10.892500
# 6  11.287500    7.250  3151324   1.138750   1.500000   1.250000   5.193750
# 7   6.012500    4.125  3245171   4.875000   6.075000   3.000000  10.892500
# 8   6.012500    4.125  3151324   1.138750   1.500000   1.250000   5.193750
# 9   6.012500    4.125  3151324   1.138750   1.500000   1.250000   5.193750
#
#    DR_HMS_DQ  DR_AMS_DQ  Avg_EMS_DQ  Avg_HMS_DQ  Avg_AMS_DQ
# 0    3.89375      3.875     7.33683    8.489732    5.008929
# 1    3.89375      3.875     7.33683    8.489732    5.008929
# 2    9.12500      8.750    12.41000   13.562500    9.375000
# 3    3.89375      3.875     7.33683    8.489732    5.008929
# 4    9.12500      8.750    12.41000   13.562500    9.375000
# 5    8.82500      8.000     7.88375    7.450000    5.500000
# 6    6.23750      5.125     3.16625    3.868750    3.187500
# 7    8.82500      8.000     7.88375    7.450000    5.500000
# 8    6.23750      5.125     3.16625    3.868750    3.187500
# 9    6.23750      5.125     3.16625    3.868750    3.187500

# %%
df1 = df.Avg_AMS
df2 = df.Avg_AMS_DQ
df3 = df.DONOR_ID
df4 = df.Avg_EMS
df5 = df.Avg_EMS_DQ
df6 = df.Avg_HMS
df7 = df.Avg_HMS_DQ

# %%
import matplotlib.pyplot as plt

# %%
plt.plot( df1, 'r')
plt.plot( df2, 'b')
plt.title('AVG_AMS') 
plt.show()

# %%
plt.plot( df4, 'r')
plt.plot( df5, 'b')
plt.title('AVG_EMS') 
plt.show()

# %%
plt.plot( df6, 'r')
plt.plot( df7, 'b')
plt.title('AVG_HMS') 
plt.show()

# %%
#taking samples to see 
df8 = df.Avg_AMS.loc[:100]
df9 = df.Avg_AMS_DQ.loc[:100]
df10 = df.Avg_EMS.loc[:100]
df11 = df.Avg_EMS_DQ.loc[:100]
df12 = df.Avg_HMS.loc[:100]
df13 = df.Avg_HMS_DQ.loc[:100]

# %%
plt.plot( df8, 'r')
plt.plot( df9, 'b')
plt.title('AVG_AMS') 

plt.show()

# %%
plt.plot( df10, 'r')
plt.plot( df11, 'b')
plt.title('AVG_EMS') 

plt.show()

# %%
plt.plot( df12, 'r')
plt.plot( df13, 'b')
plt.title('AVG_HMS') 

plt.show()

# %%
#AMS
AMS_Diff = df["Avg_AMS_DQ"] - df["Avg_AMS"]
HMS_Diff = df["Avg_EMS_DQ"]- df["Avg_EMS"]
EMS_Diff = df["Avg_HMS_DQ"]- df["Avg_HMS"]

# %%
AMS_Diff.head(10)
# Out:
# 0   -0.491071
# 1   -0.491071
# 2    3.875000
# 3   -2.491071
# 4    1.875000
# 5   -1.750000
# 6   -4.062500
# 7    1.375000
# 8   -0.937500
# 9   -0.937500
# dtype: float64

# %%
HMS_Diff.head(10)
# Out:
# 0    0.704687
# 1    0.704687
# 2    5.777857
# 3   -1.701920
# 4    3.371250
# 5   -2.661250
# 6   -7.378750
# 7    2.945625
# 8   -1.771875
# 9   -1.771875
# dtype: float64

# %%
EMS_Diff.head(10)
# Out:
# 0   -1.028125
# 1   -1.028125
# 2    4.044643
# 3   -3.885268
# 4    1.187500
# 5   -3.837500
# 6   -7.418750
# 7    1.437500
# 8   -2.143750
# 9   -2.143750
# dtype: float64

# %%
#for class two EMS,AMS and HMS

# %%
df14 = df.DR_AMS
df15 = df.DR_AMS_DQ
df16 = df.DR_EMS
df17 = df.DR_EMS_DQ
df18 = df.DR_HMS
df19 = df.DR_HMS_DQ

# %%
plt.plot( df14, 'r')
plt.plot( df15, 'b')
plt.title('ClassII_AMS') 
plt.show()

# %%
plt.plot( df16, 'r')
plt.plot( df17, 'b')
plt.title('ClassII_EMS') 
plt.show()

# %%
plt.plot( df18, 'r')
plt.plot( df19, 'b')
plt.title('ClassII_HMS') 
plt.show()

# %%
df20 = df.AB_AMS
df21 = df.AB_AMS_DQ
df22 = df.AB_EMS
df23 = df.AB_EMS_DQ
df24 = df.AB_HMS
df25 = df.AB_HMS_DQ

# %%
plt.plot( df20, 'r')
plt.plot( df21, 'b')
plt.title('ClassI_AMS') 
plt.show()

# %%
plt.plot( df22, 'r')
plt.plot( df23, 'b')
plt.title('ClassI_EMS') 
plt.show()

# %%
plt.plot( df24, 'r')
plt.plot( df25, 'b')
plt.title('ClassI_HMS') 
plt.show()
